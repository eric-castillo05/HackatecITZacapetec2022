# %%
import pandas as pd
import numpy as np
import pandas as read_csv

# %%
df = pd.read_csv("C:\\Users\\Castl\\Desktop\\Coding\\hacka\\pruebas\\comocaiga2.csv")

# %%
df.head()
entidad=int(input('Ingrese la entidad'))
municipio = int(input('Ingresa el municipio'))
sexo = int(input('Ingres su sexo'))
df.append({'ENTIDAD_REG': entidad, 'MUNICIPIO_REG':municipio, 'SEXO': sexo}, ignore_index=True)
# Out:
# Ingrese la entidad16
# Ingresa el municipio2
# Ingres su sexo1
#      ENTIDAD_REG  MUNICIPIO_REG  SEXO  EDAD
# 0           10.0           12.0   2.0  68.0
# 1           21.0           74.0   2.0  64.0
# 2           21.0          132.0   1.0  69.0
# 3           21.0          194.0   2.0  71.0
# 4           21.0          208.0   2.0  23.0
# ..           ...            ...   ...   ...
# 248         21.0           22.0   2.0  70.0
# 249         21.0          189.0   1.0  78.0
# 250         24.0           54.0   2.0  76.0
# 251         21.0          148.0   1.0  79.0
# 252         16.0            2.0   1.0   NaN
#
# [253 rows x 4 columns]

# %%
x=df.drop(['SEXO'], axis = 1).values
y = df['EDAD'].values

# %%
print(x)
# Out:
# [[ 10  12  68]
#  [ 21  74  64]
#  [ 21 132  69]
#  [ 21 194  71]
#  [ 21 208  23]
#  [ 10  13  85]
#  [ 10  14  75]
#  [ 21  74  50]
#  [ 21  85  81]
#  [ 21  41  80]
#  [ 21 214  91]
#  [ 21 154  78]
#  [ 21 154  68]
#  [ 21  53  32]
#  [ 21 141  88]
#  [ 21  17  47]
#  [ 21  71  66]
#  [ 32  40  67]
#  [ 21 132  28]
#  [ 10   7  68]
#  [ 10   7  66]
#  [ 21  54  80]
#  [ 10   8  79]
#  [ 21 116  77]
#  [ 21  41  88]
#  [ 10   7  82]
#  [  5  27  78]
#  [ 21 132  81]
#  [ 10  12  91]
#  [ 10   7  80]
#  [ 10  15  49]
#  [ 21  41  84]
#  [ 21 178  87]
#  [ 10  12  65]
#  [ 21  17  94]
#  [  7  92  65]
#  [  5  27  37]
#  [ 21  69  92]
#  [ 21  83  89]
#  [ 21 132  83]
#  [ 10  18  94]
#  [ 21 106  80]
#  [ 10   8  57]
#  [ 10   8  74]
#  [ 10  17  73]
#  [ 10   7  75]
#  [ 10   7  75]
#  [  5  30  84]
#  [  5  35  73]
#  [ 21  54  70]
#  [ 21 208  79]
#  [ 21 125  84]
#  [ 10   7  79]
#  [ 21  69  65]
#  [ 21 169  84]
#  [ 10  20  83]
#  [ 21 148  63]
#  [ 28  38  61]
# ...

# %%
print(y)
# Out:
# [68 64 69 71 23 85 75 50 81 80 91 78 68 32 88 47 66 67 28 68 66 80 79 77
#  88 82 78 81 91 80 49 84 87 65 94 65 37 92 89 83 94 80 57 74 73 75 75 84
#  73 70 79 84 79 65 84 83 63 61 20 17 57 68 75 79 90 95 47 90 60 90 93 34
#  72  1 66 65 69 77 79 82 90 67 67 64 53 38 33 93 70 50 93 84 17 61 71 18
#  76 93 90 21 58 98 62 62 20 80 90 96 25 77 34 80 81 39 35 63 51 73 65 30
#   2 54 76 73 61 92  0 64 83 61 72 88 91 83 83 89 86  0 53 21 82 72 82 66
#  90 65 80 76 62 80 69 61 87 67 91 57 63 80 86 63 53 62 72 54 86 37 80 61
#  75 66 71 67 74 70 31 48 23 55 65 67 15 74 58 88 41 89 69 85 20 87 25 85
#  89 78 59 68 76 38 94 62 32 86 94 97 28 59 89 75 90 25 75 57 67 66 61 93
#  88 63 52 78 48 72 19 87 57 71 88 73 48 46 81 85 82 69 86 71 76 73 49  1
#  51 60 76 75 59 81 78 86 70 78 76 79]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.33, random_state=0)

# %%
print(x_test)
# Out:
# [[ 21 154  86]
#  [ 21 105  64]
#  [ 21  43  71]
#  [ 10   5  98]
#  [ 21  41  69]
#  [ 27  13  62]
#  [ 21 125  65]
#  [  5  17  73]
#  [ 21 112  79]
#  [  7  93  89]
#  [ 10  25  80]
#  [ 21  83  82]
#  [ 21 153  77]
#  [ 21 180  20]
#  [ 21 132  67]
#  [ 21 156   1]
#  [ 21 196  59]
#  [ 21 156  67]
#  [  4   4  80]
#  [ 21   4  93]
#  [ 21 153  85]
#  [ 10   7  75]
#  [ 21 178   1]
#  [ 21 214  53]
#  [ 15 106  34]
#  [ 21 148  79]
#  [ 21  85  81]
#  [ 10  20  83]
#  [ 28  41  76]
#  [ 21  69  92]
#  [ 21  89  78]
#  [ 21 186   0]
#  [ 25  15  80]
#  [ 21  34  58]
#  [ 18  17  75]
#  [ 10  12  65]
#  [ 21  83  69]
#  [ 10  13  85]
#  [ 10   8  79]
#  [ 21  34  25]
#  [  5  18  92]
#  [ 21 154  68]
#  [ 21 154  28]
#  [ 21   3  65]
#  [ 21 132  93]
#  [ 10  38  61]
#  [ 21 156  49]
#  [ 10  17  73]
#  [ 21 193  90]
#  [ 19  39  74]
#  [  5  25  34]
#  [ 21  72  72]
#  [ 21 114  63]
#  [  8   9  69]
#  [ 19  39  17]
#  [ 21 154  23]
#  [ 21 139  46]
#  [ 21 132  28]
# ...

# %%
from sklearn.linear_model import LinearRegression
nl=LinearRegression()
nl.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=nl.predict(x_test)
print(y_pred)
# Out:
# [8.60000000e+01 6.40000000e+01 7.10000000e+01 9.80000000e+01
#  6.90000000e+01 6.20000000e+01 6.50000000e+01 7.30000000e+01
#  7.90000000e+01 8.90000000e+01 8.00000000e+01 8.20000000e+01
#  7.70000000e+01 2.00000000e+01 6.70000000e+01 1.00000000e+00
#  5.90000000e+01 6.70000000e+01 8.00000000e+01 9.30000000e+01
#  8.50000000e+01 7.50000000e+01 1.00000000e+00 5.30000000e+01
#  3.40000000e+01 7.90000000e+01 8.10000000e+01 8.30000000e+01
#  7.60000000e+01 9.20000000e+01 7.80000000e+01 2.91695904e-14
#  8.00000000e+01 5.80000000e+01 7.50000000e+01 6.50000000e+01
#  6.90000000e+01 8.50000000e+01 7.90000000e+01 2.50000000e+01
#  9.20000000e+01 6.80000000e+01 2.80000000e+01 6.50000000e+01
#  9.30000000e+01 6.10000000e+01 4.90000000e+01 7.30000000e+01
#  9.00000000e+01 7.40000000e+01 3.40000000e+01 7.20000000e+01
#  6.30000000e+01 6.90000000e+01 1.70000000e+01 2.30000000e+01
#  4.60000000e+01 2.80000000e+01 7.20000000e+01 4.70000000e+01
# ...

# %%
nl.predict([[10, 12, 2]])
# Out:
# array([2.])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('A vs P')
# Out:
# Text(0.5, 1.0, 'A vs P')

# %%
pred_y_df=pd.DataFrame({'Actual Value':y_test, 'Pred':y_pred, 'Difference':y_test-y_pred})
pred_y_df
# Out:
#     Actual Value  Pred    Difference
# 0             86  86.0  0.000000e+00
# 1             64  64.0 -1.421085e-14
# 2             71  71.0 -2.842171e-14
# 3             98  98.0  1.421085e-14
# 4             69  69.0 -2.842171e-14
# ..           ...   ...           ...
# 79            51  51.0 -3.552714e-14
# 80            68  68.0 -1.421085e-14
# 81            61  61.0 -3.552714e-14
# 82            79  79.0  1.421085e-14
# 83            47  47.0 -3.552714e-14
#
# [84 rows x 3 columns]

# %%
nl.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': False,
#  'copy_X': True,
#  'n_jobs': None,
#  'n_features_in_': 3,
#  'coef_': array([ 4.09453589e-15, -1.52655666e-16,  1.00000000e+00]),
#  '_residues': 4.458163447348035e-27,
#  'rank_': 3,
#  'singular_': array([880.53218894, 264.52552901,  69.48890231]),
#  'intercept_': -2.842170943040401e-14}
